# %%
import numpy as np 
import pandas as pd 
ser = pd.Series(['how', 'to', 'kick', 'ass?!'])

def capitalize_first(s):
    return s[0].upper() + s[1:]

ser_capitalized = ser.str.capitalize() 

print("Series ban đầu:")
print(ser)
print("\n" + "-"*20 + "\n")
print("Series sau khi viết hoa ký tự đầu tiên:")
print(ser_capitalized)
# Out:
# Series ban đầu:
# 0      how
# 1       to
# 2     kick
# 3    ass?!
# dtype: object
#
# --------------------
#
# Series sau khi viết hoa ký tự đầu tiên:
# 0      How
# 1       To
# 2     Kick
# 3    Ass?!
# dtype: object
